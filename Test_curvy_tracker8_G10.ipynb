# %% [markdown]
# # Teste moedas G10

# %% [markdown]
# #### Dados:
# - curvy_tracker8

# %% [markdown]
# #### Melhorias v7:
# - a pasta default é alterável (atributo data_folder)
# - USD index (all FX, EM_FX e DM/G10_FX). Salva resultado no XL e foi incluido no construtor.
# - Especificação do exception dos comandos try (FileNotFound)

# %% [markdown]
# #### Melhorias v8:
# - correcao da matriz de chg price diaria

# %%
import time
import pandas as pd
import numpy as np

# %%
import curvy_tracker8

# %%
self = curvy_tracker8.CurvyTrade(k_max=4)

# %% [markdown]
# #### Moedas:

# %%
print(self.currency_list)
# Out:
# ['AUD', 'CAD', 'CHF', 'DEM', 'GBP', 'JPY', 'NOK', 'NZD', 'SEK', 'BRL', 'CLP', 'COP', 'MXN', 'CZK', 'HUF', 'PLN', 'TRY', 'RUB', 'INR', 'HKD', 'KRW', 'SGD', 'TWD', 'ZAR']

# %%
self.currency_list_DM
# Out:
# ['AUD', 'CAD', 'CHF', 'DEM', 'GBP', 'JPY', 'NOK', 'NZD', 'SEK']

# %%
self.currency_list = list(self.currency_list_DM)
print(self.currency_list)
# Out:
# ['AUD', 'CAD', 'CHF', 'DEM', 'GBP', 'JPY', 'NOK', 'NZD', 'SEK']

# %%
list_currency_list_curve = list(self.currency_list)
list_currency_list_curve.append('USD')
print(list_currency_list_curve)
# Out:
# ['AUD', 'CAD', 'CHF', 'DEM', 'GBP', 'JPY', 'NOK', 'NZD', 'SEK', 'USD']

# %%
self.currency_list_curve = list_currency_list_curve
print(self.currency_list_curve)
# Out:
# ['AUD', 'CAD', 'CHF', 'DEM', 'GBP', 'JPY', 'NOK', 'NZD', 'SEK', 'USD']

# %%
self.run_constructor_in_parts1()
# Out:
# tickers OK -  5.6381614208221436  seconds
# spot_last OK -  6.327153205871582  seconds
# fwdpts_last OK -  5.450212478637695  seconds
# fwd_last OK -  0.042002201080322266  seconds
# fwd_discount_last OK -  0.03300166130065918  seconds
# vol EWMA OK -  1.2085235118865967  seconds
# USD index OK -  53.674952030181885  seconds

# %%
self.run_constructor_in_parts2()
# Out:
# interest_curve OK -  75.94391226768494  seconds

# %%
self.run_constructor_in_parts3()
# Out:
# NS-Fitting...: 100%|████████████████████| 74360/74360 [03:17<00:00, 376.97it/s]
# NS-all tenors OK -  204.45700788497925  seconds

# %%
self.run_constructor_in_parts4()
# Out:
# NS-Fitting...: 100%|████████████████████| 74360/74360 [03:12<00:00, 386.46it/s]
# NS-from 3 month tenor OK -  199.7623429298401  seconds

# %%
self.run_constructor_in_parts5()
# Out:
# betas OK -  0.09400510787963867  seconds
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:630: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# relative level OK -  0.44001317024230957  seconds
# Daily forward points...: 100%|███████████████████| 9/9 [00:57<00:00,  6.79s/it]
# daily fwdpts OK -  188.763409614563  seconds
# daily prices OK -  53.013444662094116  seconds
# ranks OK -  38.95669674873352  seconds

# %%
self.run_constructor_in_parts6()
# Out:
# Starting strategies
# Carry trade OK -  98.1062524318695  seconds
# Curvy trade OK -  98.0012514591217  seconds
# Level trade OK -  97.9287462234497  seconds
# Slope trade OK -  98.29924845695496  seconds
# Equal vol Carry trade OK -  109.99746203422546  seconds
# Equal vol Curvy trade OK -  109.71145820617676  seconds
# Equal vol Level trade OK -  109.56843829154968  seconds
# Equal vol Slope trade OK -  110.37946820259094  seconds

# %%
# self.run_strategy05()

# %% [markdown]
# ### Data

# %%
self.TR_df_equal_vol.plot(figsize=(12,8))
self.TR_df_equal_vol_daily.plot(figsize=(12,8))

# %%
self.GetPerformanceTable(self.TR_df_equal_vol['k2'], freq='Monthly')
# Out:
# Excess Return                   0.046404
# Volatility                      0.087086
# Sharpe                          0.532848
# Sortino                         0.753879
# Max Drawdown                   -0.301407
# Max Drawdown in Vol Terms      -3.461028
# 5th percentile in Vol Terms    -0.496062
# 10th percentile in Vol Terms   -0.339432
# Skewness                       -0.397371
# Kurtosis                        0.301779
# dtype: float64

# %%
self.GetPerformanceTable(self.TR_df_equal_vol_daily['k2'], freq='Daily')
# Out:
# Excess Return                    0.043268
# Volatility                       0.095930
# Sharpe                           0.451036
# Sortino                          0.561903
# Max Drawdown                    -0.335024
# Max Drawdown in Vol Terms       -3.492365
# 5th percentile in Vol Terms     -0.096673
# 10th percentile in Vol Terms    -0.066751
# Skewness                        -1.192419
# Kurtosis                        17.217816
# dtype: float64

# %%
# Carry trade
self.TR_df.plot(figsize=(12,8))
self.TR_df_daily.plot(figsize=(12,8))

# %%
# Curvy trade
self.TR_crv_df.plot(figsize=(12,8))
self.TR_crv_df_daily.plot(figsize=(12,8))

# %%
# Level trade
self.TR_lvl_df.plot(figsize=(12,8))
self.TR_lvl_df_daily.plot(figsize=(12,8))

# %%
# Slope trade
self.TR_slp_df.plot(figsize=(12,8))
self.TR_slp_df_daily.plot(figsize=(12,8))

# %%
# Carry (EV)
self.TR_df_equal_vol.plot(figsize=(12,8))
self.TR_df_equal_vol_daily.plot(figsize=(12,8))

# %%
# Curvy (EV)
self.TR_df_crv_equal_vol.plot(figsize=(12,8))
self.TR_df_crv_equal_vol_daily.plot(figsize=(12,8))

# %%
# Level (EV)
self.TR_df_lvl_equal_vol.plot(figsize=(12,8))
self.TR_df_lvl_equal_vol_daily.plot(figsize=(12,8))

# %%
# Slope (EV)
self.TR_df_slp_equal_vol.plot(figsize=(12,8))
self.TR_df_slp_equal_vol_daily.plot(figsize=(12,8))

# %%
df_table03 = self.table_three()
df_table03.to_excel('data\\table03_monthly.xlsx')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: PerformanceWarning: indexing past lexsort depth may impact performance.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_table03
# Out:
#                  Mean annual Stdev annual Skewness monthly Kurtosis monthly  \
# Sorting        k
# Carry trade    1     3.56246      13.3213         -1.16014          3.94699
#                2     4.70512      10.1405         -0.75122          2.22719
#                3     3.94939      8.56275        -0.563596           1.2435
#                4     3.33967      6.98404         -0.52085           1.0623
# Carry (EV)     1     2.93497      11.3068        -0.716925          2.09685
#                2     4.64035      8.70859        -0.397371         0.301779
#                3     4.60913      7.84341        -0.252701         0.962498
#                4     3.50542      6.68835        -0.464632          1.34268
# Level          1     2.28192      14.4833        -0.822731          2.59759
#                2     2.67374       10.507        -0.797982          2.82518
#                3     1.61804      8.19086        -0.664919          1.93249
#                4     1.08891      6.80817        -0.682686          1.66897
# Level (EV)     1     1.58932       12.579        -0.793324          2.00511
#                4     1.76004      5.70264       -0.0712327          2.87351
# Curvature      1     5.63331      11.9813       0.00353192          8.10743
#                2     4.14556      9.27564         0.122153          11.8397
#                3     3.02291      7.89227        -0.273681          8.06769
#                4     2.52708      6.69156        -0.562775          7.02006
# Curvature (EV) 1     5.28164      11.5885       -0.0135621          6.88978
#                2     4.36659      8.32628         0.286531          8.91977
#                3     3.10103       6.9056         -0.12264          3.67309
#                4     2.21721      5.97032        -0.756221          12.5505
#
#                  Sharpe ratio
# Sorting        k
# Carry trade    1     0.193221
#                2     0.376368
#                3     0.316964
#                4     0.283953
# Carry (EV)     1     0.187841
#                2     0.451036
#                3     0.395606
#                4      0.31906
# Level          1     0.137056
#                2     0.208602
#                3     0.182423
#                4     0.181851
# Level (EV)     1     0.112401
#                2     0.171798
#                3     0.135997
#                4     0.153168
# Slope          1     0.107583
#                2     0.138567
#                3     0.195653
#                4     0.141397
# Slope (EV)     1     0.243498
#                2      0.32553
#                3     0.364264
#                4     0.308635
# Curvature      1     0.470176
#                2      0.44693
#                3     0.383021
#                4     0.377652
# Curvature (EV) 1     0.455767
#                2     0.524435
#                3      0.44906
#                4     0.371373

# %%
self.run_table_four_five()
# Out:
# tables 4 and 5 OK -  0.031001567840576172  seconds

# %%
self.table04_Funding.to_excel('data\\table04_funding.xlsx')
self.table04_Funding
# Out:
#                     AUD  CAD  CHF  DEM  GBP  JPY  NOK  NZD  SEK
# Strategy         k
# Forward discount 1    1    0  120    1    0  217    2    0    1
#                  2    9   16  310   19    0  278    4    1   47
#                  3   23   63  318  151   11  308   30   11  111
#                  4   27  120  329  234   56  342   74   21  165
# Curvature        1    7   34    6   64   34  140    4    4   49
#                  2   10  105   54  120   66  207   32   12   78
#                  3   25  135  154  199   83  250   45   35  100
#                  4   58  170  240  267  107  271   62   64  129

# %%
self.table05_Investing.to_excel('data\\table05_investing.xlsx')
self.table05_Investing
# Out:
#                     AUD  CAD  CHF  DEM  GBP  JPY  NOK  NZD  SEK
# Strategy         k
# Forward discount 1   58    0    0    9   10    0   55  177   33
#                  2  195    6    0   23   51    0   75  284   50
#                  3  278   42    2   47  108    0  190  292   67
#                  4  305  109    4   84  197    0  236  304  129
# Curvature        1   50   28    0    0  125    6   41   62   30
#                  2  123   58    6    7  158   17  106  139   70
#                  3  183   92   31   14  189   33  177  197  110
#                  4  249  129   62   40  215   54  236  234  149

# %%
self.USD_index
# Out:
#                 USD   USD_DM USD_EM
# 1991-01-01      100      100    100
# 1991-01-02  99.4408  99.4408    NaN
# 1991-01-03  99.2196  99.2196    NaN
# 1991-01-04  99.7826  99.7826    NaN
# 1991-01-07  100.795  100.795    NaN
# 1991-01-08  100.721  100.721    NaN
# 1991-01-09  100.241  100.241    NaN
# 1991-01-10  100.538  100.538    NaN
# 1991-01-11  100.437  100.437    NaN
# 1991-01-14  100.684  100.684    NaN
# 1991-01-15  100.709  100.709    NaN
# 1991-01-16  100.694  100.694    NaN
# 1991-01-17   99.665   99.665    NaN
# 1991-01-18  99.3162  99.3162    NaN
# 1991-01-21   98.831   98.831    NaN
# 1991-01-22  98.9899  98.9899    NaN
# 1991-01-23  98.7088  98.7088    NaN
# 1991-01-24  98.8088  98.8088    NaN
# 1991-01-25  98.9946  98.9946    NaN
# 1991-01-28  98.7827  98.7827    NaN
# 1991-01-29  98.6841  98.6841    NaN
# 1991-01-30  98.7535  98.7535    NaN
# 1991-01-31  98.4816  98.4816    NaN
# 1991-02-01  98.1704  98.1704    NaN
# 1991-02-04  97.9463  97.9463    NaN
# 1991-02-05  97.8195  97.8195    NaN
# 1991-02-06  97.2131  97.2131    NaN
# 1991-02-07  97.1592  97.1592    NaN
# 1991-02-08  97.4889  97.4889    NaN
# 1991-02-11  97.0991  97.0991    NaN
# ...             ...      ...    ...
# 2019-05-22  124.849  124.849    NaN
# 2019-05-23  124.563  124.563    NaN
# 2019-05-24  124.043  124.043    NaN
# 2019-05-27  124.269  124.269    NaN
# 2019-05-28  124.471  124.471    NaN
# 2019-05-29  124.659  124.659    NaN
# 2019-05-30  124.679  124.679    NaN
# 2019-05-31  124.174  124.174    NaN
# 2019-06-03  123.463  123.463    NaN
# 2019-06-04  123.289  123.289    NaN
# 2019-06-05  123.536  123.536    NaN
# 2019-06-06  123.218  123.218    NaN
# 2019-06-07  122.662  122.662    NaN
# 2019-06-10  123.074  123.074    NaN
# 2019-06-11   123.13   123.13    NaN
# 2019-06-12   123.49   123.49    NaN
# 2019-06-13   123.55   123.55    NaN
# 2019-06-14  124.217  124.217    NaN
# 2019-06-17  124.313  124.313    NaN
# 2019-06-18  124.263  124.263    NaN
# 2019-06-19  123.748  123.748    NaN
# 2019-06-20  122.709  122.709    NaN
# 2019-06-21  122.347  122.347    NaN
# 2019-06-24  121.924  121.924    NaN
# 2019-06-25  122.095  122.095    NaN
# 2019-06-26  121.937  121.937    NaN
# 2019-06-27  121.873  121.873    NaN
# 2019-06-28   121.83   121.83    NaN
# 2019-07-01   122.65   122.65    NaN
# 2019-07-02  122.463  122.463    NaN
#
# [7436 rows x 3 columns]

# %%
self.USD_index.plot(figsize=(12,8), logy=True)

# %%
self.plot_vols((12,8))

# %%
# nproocessors=3
# processes = []
# with ProcessPoolExecutor(max_workers=nproocessors) as executor:
#     processes.append(executor.submit(self.run_strategy01))
#     processes.append(executor.submit(self.run_strategy02))
#     processes.append(executor.submit(self.run_strategy03))
#     processes.append(executor.submit(self.run_strategy04))
#     wait(processes)
# results = {}
# for process in processes:
#     results.update(process.result())

# %%
# nproocessors=4
# with ProcessPoolExecutor(max_workers=nproocessors) as executor:
#     executor.submit(self.run_strategy01,)
#     executor.submit(self.run_strategy02,)
#     executor.submit(self.run_strategy03,)
#     executor.submit(self.run_strategy04,)

# %% [markdown]
# ## Additional data for presentation

# %%
self.fwd_discount_last.loc[self.monthly_calendar].plot(figsize=(12,8))

# %%
self.fwd_discount_last.rolling(21).mean().plot(figsize=(12,8))

# %%
self.fwd_discount_last.rolling(2).mean().loc['1999-10':'1999-12'].plot(figsize=(12,8))
